# %% [markdown]
# # Python Arithmetic
#
# In programming and math, these are expressions that follow the rules of PEMDAS. Below are the symbols used in Python for mathematical expressions.
#
# ## Operators in Python

# %%
# Parentheses
(1 + 1) * 3
# Out:
# 6

# %%
# Exponent: Notice it has two * characters and no spaces in between.
2 ** 4
# Out:
# 16

# %%
# Multiplication
2 * 4
# Out:
# 8

# %%
# Division
9 / 8
# Out:
# 1.125

# %%
# Integer Division: Notice it has two / characters and no spaces in between.
9 // 8
# Out:
# 1

# %%
# Modulo Division
5 % 2
# Out:
# 1

# %%
# Addition
2 + 6
# Out:
# 8

# %%
# Subtraction
4 - 2
# Out:
# 2

# %% [markdown]
# ***QUESTION: What is the difference between Integer Division and Modulo Division?***

# %% [markdown]
# ## Expression Errors in Python

# %%
# Read the Exception Message, what does it mean?
* 4
# Out:
#   Cell In[9], line 2
#     * 4
#     ^
# SyntaxError: can't use starred expression here

# %%
# Read the Exception Message, what can tell you where to start troubleshooting?
2 * * 4
# Out:
#   Cell In[10], line 2
#     2 * * 4
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Example Expressions
#
# Using the rules of PEMDAS, predict how each expression will be evaluated.

# %%
# Expression 1
2 + 3 * -5
# Out:
# -13

# %%
# Expression 2
(2 + 3) * -5
# Out:
# -25

# %%
# Expression 3
-(1 + 1) + 2 * (3 * 4 * 5 / 6) ** 3 + 7 + 8 + 9
# Out:
# 2022.0

# %% [markdown]
# ## Text Data Type
#
# You can use either the single or double quote when creating a String value. The key is, if you open with a double quote you must close it with a double quote, and vice versa.

# %%
# String Using Single Quote
'Hello'
# Out:
# 'Hello'

# %%
# String Using Double Quote
"World"
# Out:
# 'World'

# %% [markdown]
# ## Identifer Names
#
# ### Rules
#
# 1. May only use alphabet or numerical characters
# 1. May use the underscore _ character
# 1. First character must be a letter or underscore
# 1. Should try to ensure name has meaning to the expression or value
# 1. Identifer name is first, then equal sign to assign an expression or value
#
# ### Example
#
# * identifier = "value"
# * x = 1
# * sample = 1 / 2
# * snake_case = "Identifer name uses underscore to separate words. Preferred"
# * camelCase = "Identifer name uses capital letters to separate words."
#
# ### Assigning a Value
#
# * The expression or call must first be completed
# * Result is then assigned to the identifier
#
# Let's assign the variable _a_:

# %%
a = 2

# %%
a
# Out:
# 2

# %% [markdown]
# ***QUESTION: What will happen when we attempt to use variable _b_?***

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
b = 3
a + b
# Out:
# 5

# %% [markdown]
# ***QUESTION: Can we use the result of _a + b_ in future expressions?***

# %%
# COMPLETE: Assign the result of a plus b
total = a + b
total
# Out:
# 5

# %% [markdown]
# ***QUESTION: What will happen to variable _total_ if we reassign variable _a_ to a new value?***

# %%
a = 10
total
# Out:
# 5

# %%
# COMPLETE: Reassign result of expression a plus b to total
total = a + b
total
# Out:
# 13

# %%
# The line below causes a syntax error
a + b = total
# Out:
#   Cell In[23], line 2
#     a + b = total
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a = a + 1
a
# Out:
# 11

# %%
# What does this do?
x = 100
y = 10.25
z = x * y
z
# Out:
# 1025.0

# %% [markdown]
# ### Why Names?
#
# A cell with arithmetic but no names is difficult to interpret.

# %% [markdown]
# ***QUESTION: Without scrolling down, what does Option 1 represent?***

# %%
# Option 1
40 * 15.00
# Out:
# 600.0

# %%
40 * 52 * 15.00
# Out:
# 31200.0

# %% [markdown]
# ***QUESTION: After reading the variable assignments, what does Option 2 represent?***

# %%
# Option 2
ca_hourly_minimum_wage = 15.00
hours_per_week = 40
weeks_per_year = 52

# %%
hours_per_year = hours_per_week * weeks_per_year

# %%
hours_per_year
# Out:
# 2080

# %%
weekly_wages = hours_per_week * ca_hourly_minimum_wage
weekly_wages
# Out:
# 600.0

# %%
yearly_wages = hours_per_year * ca_hourly_minimum_wage
yearly_wages
# Out:
# 31200.0

# %% [markdown]
# ***QUESTION: Compare Option 1 and 2, which one demonstrates how on January 1, 2022, the CA Minimum Wage for Employers with 26 Employees or More increased to $15/hour better? Why?***

# %% [markdown]
# ## Functions and Call Expressions
#
# When a function is used, we say it is "called". Which means you will use the function identifier with a pair of parentheses and any required arguments inside those parenthese to complete the call.
#
# Below are a few example functions that you can call.
#
# ### Absolute Value

# %%
abs(-5)
# Out:
# 5

# %%
abs(1 - 3)
# Out:
# 2

# %%
day_temp = 52
night_temp = 47
abs(night_temp - day_temp)
# Out:
# 5

# %% [markdown]
# ### Minimum and Maximum

# %%
min(14, 15)
# Out:
# 14

# %%
max(24, 42)
# Out:
# 42

# %% [markdown]
# ### Rounding
#
# This uses a combination of positional arguments and named arguments.

# %%
round(123.456)
# Out:
# 123

# %%
round(123.456, 1)
# Out:
# 123.5

# %%
round(123.456, ndigits=1)
# Out:
# 123.5

# %%
round?
# Out:
# Signature: round(number, ndigits=None)
# Docstring:
# Round a number to a given precision in decimal digits.
#
# The return value is an integer if ndigits is omitted or None.  Otherwise
# the return value has the same type as the number.  ndigits may be negative.
# Type:      builtin_function_or_method

# %%
round(number=123.456)
# Out:
# 123

# %%
# The line below causes a type error because the wrong name was used.
round(123.456, digs=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 # The line below causes a type error because the wrong name was used.
# ----> 2 round(123.456, digs=1)
#
# TypeError: 'digs' is an invalid keyword argument for round()

# %% [markdown]
# ### Imported Functions
#
# There are far more functions available to you than what is in the default install of Python. An import is a way to bring additional functions and classes into your program to do more things.
#
# Just a note for how functions are described. A _method_ is a function that belongs to a class in Python. A _function_ is independent of a class. We will get more into this later, but you may hear the term method or function used.
#
# For example, we can import the _math_ library and check the square root of a number.

# %%
# The line below causes an error if math has not been imported
math.sqrt(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 # The line below causes an error if math has not been imported
# ----> 2 math.sqrt(2)
#
# NameError: name 'math' is not defined

# %%
import math

# %%
math.sqrt(2)
# Out:
# 1.4142135623730951

# %% [markdown]
# ## Tables
#
# This is one of the most important things we will use in this class. Tables are a way to organize your data for analysis and graphing.
#
# Below are a few of the most common methods used in this class.

# %%
# Import all Classes and Functions from the datascience library before you can use it.
from datascience import *

# %%
# Read a CSV file and convert it into a table in Python memory
cones = Table.read_table('cones.csv')
cones
# Out:
# Flavor     | Color       | Price
# strawberry | pink        | 3.55
# chocolate  | light brown | 4.75
# chocolate  | dark brown  | 5.25
# strawberry | pink        | 5.25
# chocolate  | dark brown  | 5.25
# bubblegum  | pink        | 4.75

# %% [markdown]
# ### Show Method
#
# Displays the first n rows of a table. If no n is provided, displays all rows.

# %%
cones.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Flavor</th> <th>Color</th> <th>Price</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>strawberry</td> <td>pink       </td> <td>3.55 </td>
#         </tr>
#         <tr>
#             <td>chocolate </td> <td>light brown</td> <td>4.75 </td>
#         </tr>
#         <tr>
#             <td>chocolate </td> <td>dark brown </td> <td>5.25 </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (3 rows omitted)</p>

# %%
cones.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Flavor</th> <th>Color</th> <th>Price</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>strawberry</td> <td>pink       </td> <td>3.55 </td>
#         </tr>
#         <tr>
#             <td>chocolate </td> <td>light brown</td> <td>4.75 </td>
#         </tr>
#         <tr>
#             <td>chocolate </td> <td>dark brown </td> <td>5.25 </td>
#         </tr>
#         <tr>
#             <td>strawberry</td> <td>pink       </td> <td>5.25 </td>
#         </tr>
#         <tr>
#             <td>chocolate </td> <td>dark brown </td> <td>5.25 </td>
#         </tr>
#         <tr>
#             <td>bubblegum </td> <td>pink       </td> <td>4.75 </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ### Select Method
#
# Creates a copy of a table with only the selected columns. Each column is the column name as a string or the integer index of the column.

# %%
cones.select('Flavor')
# Out:
# Flavor
# strawberry
# chocolate
# chocolate
# strawberry
# chocolate
# bubblegum

# %%
cones.select('Flavor', 'Price')
# Out:
# Flavor     | Price
# strawberry | 3.55
# chocolate  | 4.75
# chocolate  | 5.25
# strawberry | 5.25
# chocolate  | 5.25
# bubblegum  | 4.75

# %%
# The line below causes an error because Flavor is not a name.
cones.select(Flavor, 'Price')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 # The line below causes an error because Flavor is not a name.
# ----> 2 cones.select(Flavor, 'Price')
#
# NameError: name 'Flavor' is not defined

# %% [markdown]
# ### Drop Method
#
# Creates a copy of a table without the specified columns. Each column is the column name as a string or integer index.

# %%
cones.drop('Price')
# Out:
# Flavor     | Color
# strawberry | pink
# chocolate  | light brown
# chocolate  | dark brown
# strawberry | pink
# chocolate  | dark brown
# bubblegum  | pink

# %%
cones
# Out:
# Flavor     | Color       | Price
# strawberry | pink        | 3.55
# chocolate  | light brown | 4.75
# chocolate  | dark brown  | 5.25
# strawberry | pink        | 5.25
# chocolate  | dark brown  | 5.25
# bubblegum  | pink        | 4.75

# %%
cones_without_price = cones.drop('Price')
cones_without_price
# Out:
# Flavor     | Color
# strawberry | pink
# chocolate  | light brown
# chocolate  | dark brown
# strawberry | pink
# chocolate  | dark brown
# bubblegum  | pink

# %% [markdown]
# ### Where Method
#
# Filters the table for rows where the predicate is true. Predicate should be one of the provided are.<something> functions. Column can be a string column label or an integer index.

# %%
cones.where('Flavor', 'chocolate')
# Out:
# Flavor    | Color       | Price
# chocolate | light brown | 4.75
# chocolate | dark brown  | 5.25
# chocolate | dark brown  | 5.25

# %% [markdown]
# ### Sort Method
#
# Sorts the rows in the table by the values in the column column_name_or_index in ascending order by default. Set descending=True to sort in descending order.

# %%
cones.sort('Price')
# Out:
# Flavor     | Color       | Price
# strawberry | pink        | 3.55
# chocolate  | light brown | 4.75
# bubblegum  | pink        | 4.75
# chocolate  | dark brown  | 5.25
# strawberry | pink        | 5.25
# chocolate  | dark brown  | 5.25

# %%
cones.sort('Price', descending=True)
# Out:
# Flavor     | Color       | Price
# chocolate  | dark brown  | 5.25
# strawberry | pink        | 5.25
# chocolate  | dark brown  | 5.25
# chocolate  | light brown | 4.75
# bubblegum  | pink        | 4.75
# strawberry | pink        | 3.55

# %%
cones.sort('Flavor', descending=True)
# Out:
# Flavor     | Color       | Price
# strawberry | pink        | 3.55
# strawberry | pink        | 5.25
# chocolate  | light brown | 4.75
# chocolate  | dark brown  | 5.25
# chocolate  | dark brown  | 5.25
# bubblegum  | pink        | 4.75

# %% [markdown]
# ### A more interesting table

# %%
# From https://github.com/erikgregorywebb/datasets/blob/master/nba-salaries.csv
nba = Table.read_table('nba_salaries.csv')
nba
# Out:
# rank | name             | position | team                   | salary   | season
# 1    | Shaquille O'Neal | C        | Los Angeles Lakers     | 17142000 | 2000
# 2    | Kevin Garnett    | PF       | Minnesota Timberwolves | 16806000 | 2000
# 3    | Alonzo Mourning  | C        | Miami Heat             | 15004000 | 2000
# 4    | Juwan Howard     | PF       | Washington Wizards     | 15000000 | 2000
# 5    | Scottie Pippen   | SF       | Portland Trail Blazers | 14795000 | 2000
# 6    | Karl Malone      | PF       | Utah Jazz              | 14000000 | 2000
# 7    | Larry Johnson    | F        | New York Knicks        | 11910000 | 2000
# 8    | Gary Payton      | PG       | Seattle SuperSonics    | 11020000 | 2000
# 9    | Rasheed Wallace  | PF       | Portland Trail Blazers | 10800000 | 2000
# 10   | Shawn Kemp       | C        | Cleveland Cavaliers    | 10780000 | 2000
# ... (9446 rows omitted)

# %% [markdown]
# ***QUESTION: How many rows does the table above have?***

# %%
point_guards = nba.where('position', 'PG').where('season', 2020)

# %%
point_guards
# Out:
# rank | name              | position | team                   | salary   | season
# 1    | Stephen Curry     | PG       | Golden State Warriors  | 40231758 | 2020
# 2    | Chris Paul        | PG       | Oklahoma City Thunder  | 38506482 | 2020
# 3    | Russell Westbrook | PG       | Houston Rockets        | 38506482 | 2020
# 4    | John Wall         | PG       | Washington Wizards     | 38199000 | 2020
# 8    | Kyle Lowry        | PG       | Toronto Raptors        | 34996296 | 2020
# 14   | Kemba Walker      | PG       | Boston Celtics         | 32742000 | 2020
# 16   | Mike Conley       | PG       | Utah Jazz              | 32511624 | 2020
# 17   | Kyrie Irving      | PG       | Brooklyn Nets          | 31742000 | 2020
# 21   | Damian Lillard    | PG       | Portland Trail Blazers | 29802321 | 2020
# 52   | Malcolm Brogdon   | PG       | Indiana Pacers         | 20000000 | 2020
# ... (72 rows omitted)

# %% [markdown]
# ***QUESTION: How many rows does the table above have?***

# %%
point_guards.drop('position')
# Out:
# rank | name              | team                   | salary   | season
# 1    | Stephen Curry     | Golden State Warriors  | 40231758 | 2020
# 2    | Chris Paul        | Oklahoma City Thunder  | 38506482 | 2020
# 3    | Russell Westbrook | Houston Rockets        | 38506482 | 2020
# 4    | John Wall         | Washington Wizards     | 38199000 | 2020
# 8    | Kyle Lowry        | Toronto Raptors        | 34996296 | 2020
# 14   | Kemba Walker      | Boston Celtics         | 32742000 | 2020
# 16   | Mike Conley       | Utah Jazz              | 32511624 | 2020
# 17   | Kyrie Irving      | Brooklyn Nets          | 31742000 | 2020
# 21   | Damian Lillard    | Portland Trail Blazers | 29802321 | 2020
# 52   | Malcolm Brogdon   | Indiana Pacers         | 20000000 | 2020
# ... (72 rows omitted)

# %%
point_guards
# Out:
# rank | name              | position | team                   | salary   | season
# 1    | Stephen Curry     | PG       | Golden State Warriors  | 40231758 | 2020
# 2    | Chris Paul        | PG       | Oklahoma City Thunder  | 38506482 | 2020
# 3    | Russell Westbrook | PG       | Houston Rockets        | 38506482 | 2020
# 4    | John Wall         | PG       | Washington Wizards     | 38199000 | 2020
# 8    | Kyle Lowry        | PG       | Toronto Raptors        | 34996296 | 2020
# 14   | Kemba Walker      | PG       | Boston Celtics         | 32742000 | 2020
# 16   | Mike Conley       | PG       | Utah Jazz              | 32511624 | 2020
# 17   | Kyrie Irving      | PG       | Brooklyn Nets          | 31742000 | 2020
# 21   | Damian Lillard    | PG       | Portland Trail Blazers | 29802321 | 2020
# 52   | Malcolm Brogdon   | PG       | Indiana Pacers         | 20000000 | 2020
# ... (72 rows omitted)

# %% [markdown]
# ***QUESTION: Why is the position column still present when we run the table a second time?***

# %%
# COMPLETE: Update the point_guards table to exclude the rank, position, and season columns.
point_guards = point_guards.drop('rank', 'position', 'season')

# %%
# COMPLETE: Output the first 10 rows of the table
point_guards.show(10)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>name</th> <th>team</th> <th>salary</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Stephen Curry    </td> <td>Golden State Warriors </td> <td>40231758</td>
#         </tr>
#         <tr>
#             <td>Chris Paul       </td> <td>Oklahoma City Thunder </td> <td>38506482</td>
#         </tr>
#         <tr>
#             <td>Russell Westbrook</td> <td>Houston Rockets       </td> <td>38506482</td>
#         </tr>
#         <tr>
#             <td>John Wall        </td> <td>Washington Wizards    </td> <td>38199000</td>
#         </tr>
#         <tr>
#             <td>Kyle Lowry       </td> <td>Toronto Raptors       </td> <td>34996296</td>
#         </tr>
#         <tr>
#             <td>Kemba Walker     </td> <td>Boston Celtics        </td> <td>32742000</td>
#         </tr>
#         <tr>
# ...

# %%
# COMPLETE: Sort the point_guards table by salary descending and output the first 10 rows
point_guards.sort('salary', descending=True).show(10)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>name</th> <th>team</th> <th>salary</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Stephen Curry    </td> <td>Golden State Warriors </td> <td>40231758</td>
#         </tr>
#         <tr>
#             <td>Chris Paul       </td> <td>Oklahoma City Thunder </td> <td>38506482</td>
#         </tr>
#         <tr>
#             <td>Russell Westbrook</td> <td>Houston Rockets       </td> <td>38506482</td>
#         </tr>
#         <tr>
#             <td>John Wall        </td> <td>Washington Wizards    </td> <td>38199000</td>
#         </tr>
#         <tr>
#             <td>Kyle Lowry       </td> <td>Toronto Raptors       </td> <td>34996296</td>
#         </tr>
#         <tr>
#             <td>Kemba Walker     </td> <td>Boston Celtics        </td> <td>32742000</td>
#         </tr>
#         <tr>
# ...

# %% [markdown]
# ***QUESTION: Why does the line below cause an error?***

# %%
nba.drop('position').where('position', 'PG')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 nba.drop('position').where('position', 'PG')
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/datascience/tables.py:1404, in Table.where(self, column_or_label, value_or_predicate, other)
#    1322 def where(self, column_or_label, value_or_predicate=None, other=None):
#    1323     """
#    1324     Return a new ``Table`` containing rows where ``value_or_predicate``
#    1325     returns True for values in ``column_or_label``.
#    (...)   1402     Color | Shape | Amount | Price
#    1403     """
# -> 1404     column = self._get_column(column_or_label)
#    1405     if other is not None:
#    1406         assert callable(value_or_predicate), "Predicate required for 3-arg where"
#
# ...
