# %%
from datascience import *
import numpy as np

# %% [markdown]
# # Big Picture View of Statistics #

# %% [markdown]
# ## Why Statistics? ##

# %% [markdown]
# ### Two Main Types of Statistical Studies ###

# %% [markdown]
# ### Vocabulary ###

# %% [markdown]
# Population:
#
# Sample:
#
# Variable:
#
# Outcome:

# %% [markdown]
# ### Two Main Types of Variables ###

# %% [markdown]
# ## Correlation (Association) vs. Causation ##

# %% [markdown]
# ### Association ###

# %% [markdown]
# ### Causation ###
