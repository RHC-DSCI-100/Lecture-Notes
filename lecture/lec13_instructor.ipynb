# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action='ignore', category=DeprecationWarning)

# %% [markdown]
# ## Comparison
#
# There are 6 basic comparison operators:
#
# * Greater Than: >
# * Greater Than or Equal To: >=
# * Less Than: <
# * Less Than or Equal To: <=
# * Equal To: ==
# * Not Equal To: !=
#
# To use these, you must have two operands on either side of one of the operators above. In addition, there are 3 logical operators:
#
# * AND: All parts must be true for the whole to be true
# * OR: One part must be true for the whole to be true
# * NOT: Means the opposite; False becomes True and True becomes False

# %%
3 > 1
# Out:
# True

# %%
type(3 > 1)
# Out:
# bool

# %% [markdown]
# In the code below, try changing the capital T in True to a lowercase t and see what happens?

# %%
True
# Out:
# True

# %% [markdown]
# Do not run the block below until you consider what the code does. What will be the result of the lines after the variables x and y are set?

# %%
x = 14
y = 3

# What does this line of code do?
x = y

# What is the result of this line of code?
print(x == y)

# What is the result of this line of code?
print(x != y)
# Out:
# True
# False

# %%
x = 11
y = 42

# %%
x > 15
# Out:
# False

# %%
12 < x
# Out:
# False

# %%
x < 20
# Out:
# True

# %%
12 < x < 20
# Out:
# False

# %%
10 < y-x < 13
# Out:
# False

# %%
x > 13 and y < 3.14159
# Out:
# False

# %% [markdown]
# (The comparison `12 < x < 20` is equivalent to `12 < x and x < 20`.)

# %%
print(f'12 < {x} or {x} > 20')
print(f'{12 < x} or {x > 20}')
print(f'{12 < x or x > 20}')
# Out:
# 12 < 11 or 11 > 20
# False or False
# False

# %%
print(f'12 < {y} or {y} > 20')
print(f'{12 < y} or {y > 20}')
print(f'{12 < y or y > 20}')
# Out:
# 12 < 42 or 42 > 20
# True or True
# True

# %%
x = x ** 2
y = y % 3
x, y
# Out:
# (121, 0)

# %%
print(f'12 < {x} or {y} > 20')
print(f'{12 < x} or {y > 20}')
print(f'{12 < x or y > 20}')
# Out:
# 12 < 121 or 0 > 20
# True or False
# True

# %%
x = 2
y = 3
z = 4
print(f'{x} > {z} and -5 < {x} or {y} > 3')
print(f'{x > z} and {-5 < x} or {y >= 3}')
print(f'{x > z and -5 < x} or {y >= 3}')
print(f'{x > z and -5 < x or y >= 3}')
# Out:
# 2 > 4 and -5 < 2 or 3 > 3
# False and True or True
# False or True
# True

# %% [markdown]
# ## Comparisons with arrays

# %%
pets = make_array('cat', 'cat', 'dog', 'cat', 'dog', 'rabbit')

# %%
# Compare the array to the value cat
cats = pets == 'cat'
cats
# Out:
# array([ True,  True, False,  True, False, False], dtype=bool)

# %%
1 + 1 + 0 + 1 + 0 + 0
# Out:
# 3

# %%
sum(make_array(True, True, False, True, False, False))
# Out:
# 3

# %%
sum(pets == 'dog')
# Out:
# 2

# %%
np.count_nonzero(pets == 'dog')
# Out:
# 2

# %%
x = np.arange(20, 31)

# %%
x >= 28
# Out:
# array([False, False, False, False, False, False, False, False,  True,
#         True,  True], dtype=bool)

# %%
sum(x >= 28)
# Out:
# 3

# %% [markdown]
# ## Rows & Apply

# %%
survey = Table.read_table('welcome_survey_sp22.csv')
survey.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Year</th> <th>Extroversion</th> <th>Number of textees</th> <th>Hours of sleep</th> <th>Handedness</th> <th>Pant leg</th> <th>Sleep position</th> <th>Pets</th> <th>Piercings</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Second</td> <td>5           </td> <td>5                </td> <td>8             </td> <td>Left-handed </td> <td>Left leg in first </td> <td>On your left side</td> <td>Ants                          </td> <td>0        </td>
#         </tr>
#         <tr>
#             <td>Fourth</td> <td>2           </td> <td>3                </td> <td>7             </td> <td>Right-handed</td> <td>Left leg in first </td> <td>On your left side</td> <td>Beetles, Centipedes, Scorpions</td> <td>0        </td>
#         </tr>
#         <tr>
# ...

# %%
r = survey.row(0)

# %%
r
# Out:
# Row(Year='Second', Extroversion=5, Number of textees=5, Hours of sleep=8.0, Handedness='Left-handed', Pant leg='Left leg in first', Sleep position='On your left side', Pets='Ants', Piercings=0)

# %%
r.item(0)
# Out:
# 'Second'

# %%
r.item('Year')
# Out:
# 'Second'

# %%
np.average(survey.select(1, 2, 3).row(2))
# Out:
# 5.0

# %%
p = survey.pivot(6, 3)
p.with_column('Total', p.drop(0).apply(sum))
# Out:
# Hours of sleep | On your back | On your left side | On your right side | On your stomach | Total
# 3              | 0            | 1                 | 1                  | 0               | 2
# 4              | 8            | 2                 | 4                  | 3               | 17
# 5              | 15           | 13                | 23                 | 9               | 60
# 5.5            | 1            | 0                 | 2                  | 0               | 3
# 6              | 51           | 87                | 91                 | 33              | 262
# 6.5            | 5            | 1                 | 5                  | 1               | 12
# 7              | 123          | 119               | 183                | 58              | 483
# 7.5            | 11           | 9                 | 5                  | 6               | 31
# 8              | 77           | 83                | 136                | 62              | 358
# ...

# %% [markdown]
# ## Conditional Statements

# %%
x = 20

# %%
if x >= 18:
    print('You can legally vote.')
# Out:
# You can legally vote.

# %%
if x >= 21:
    print('You can legally drink.')

# %%
def age(x):
    if x >= 18:
        return 'You can legally vote.'
    if x >= 21:
        return 'You can legally drink.'

# %%
age(3)

# %%
age(20)
# Out:
# 'You can legally vote.'

# %%
age(25)
# Out:
# 'You can legally vote.'

# %%
def age(x):
    if x > 20:
        return 'You can legally vote and drink.'
    elif x >= 18:
        return 'You can legally vote.'
    else:
        return 'You can legally drink milk.'

# %%
age(3)
# Out:
# 'You can legally drink milk.'

# %%
age(20)
# Out:
# 'You can legally vote.'

# %%
age(21)
# Out:
# 'You can legally vote and drink.'

# %%
trip = Table().read_table('trip.csv')
trip.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Trip ID</th> <th>Duration</th> <th>Start Date</th> <th>Start Station</th> <th>Start Terminal</th> <th>End Date</th> <th>End Station</th> <th>End Terminal</th> <th>Bike #</th> <th>Subscriber Type</th> <th>Zip Code</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>913460 </td> <td>765     </td> <td>8/31/2015 23:26</td> <td>Harry Bridges Plaza (Ferry Building)</td> <td>50            </td> <td>8/31/2015 23:39</td> <td>San Francisco Caltrain (Townsend at 4th)</td> <td>70          </td> <td>288   </td> <td>Subscriber     </td> <td>2139    </td>
#         </tr>
#         <tr>
#             <td>913459 </td> <td>1036    </td> <td>8/31/2015 23:11</td> <td>San Antonio Shopping Center         </td> <td>31            </td> <td>8/31/2015 23:28</td> <td>Mountain View City Hall                 </td> <td>27          </td> <td>35    </td> <td>Subscriber     </td> <td>95032   </td>
# ...

# %%
def trip_kind(start, end):
    if start == end:
        return 'round trip'
    else:
        return 'one way'

kinds = trip.with_column('Trip Kind', trip.apply(trip_kind, 'Start Station', 'End Station'))
kinds.show(10)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Trip ID</th> <th>Duration</th> <th>Start Date</th> <th>Start Station</th> <th>Start Terminal</th> <th>End Date</th> <th>End Station</th> <th>End Terminal</th> <th>Bike #</th> <th>Subscriber Type</th> <th>Zip Code</th> <th>Trip Kind</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>913460 </td> <td>765     </td> <td>8/31/2015 23:26</td> <td>Harry Bridges Plaza (Ferry Building)         </td> <td>50            </td> <td>8/31/2015 23:39</td> <td>San Francisco Caltrain (Townsend at 4th)     </td> <td>70          </td> <td>288   </td> <td>Subscriber     </td> <td>2139    </td> <td>one way  </td>
#         </tr>
#         <tr>
# ...

# %%
kinds.where('Duration', are.below(600)).pivot('Trip Kind', 'Start Station')
# Out:
# Start Station                    | one way | round trip
# 2nd at Folsom                    | 3879    | 17
# 2nd at South Park                | 3092    | 47
# 2nd at Townsend                  | 5526    | 42
# 5th at Howard                    | 3308    | 16
# Adobe on Almaden                 | 262     | 2
# Arena Green / SAP Center         | 191     | 13
# Beale at Market                  | 3307    | 19
# Broadway St at Battery St        | 2670    | 33
# California Ave Caltrain Station  | 25      | 6
# Castro Street and El Camino Real | 581     | 7
# ... (60 rows omitted)

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Use Conditional Statements and Random Selection to Create Simulations

# %% [markdown]
# Let's play a game: we each roll a die.
#
# If my number is bigger: you pay me a dollar.
#
# If they're the same: we do nothing.
#
# If your number is bigger: I pay you a dollar.

# %% [markdown]
# Steps:
# 1. Find a way to simulate two dice rolls.
# 2. Compute how much money we win/lose based on the result.
# 3. Do steps 1 and 2 10,000 times.

# %% [markdown]
# ### Conditional Statements

# %%
# Work in progress
def one_round(my_roll, your_roll):
    if my_roll > your_roll:
        return 1

# %%
one_round(4, 3)
# Out:
# 1

# %%
one_round(2, 6)

# %%
# Final correct version
def one_round(my_roll, your_roll):
    if my_roll > your_roll:
        return 1
    elif my_roll < your_roll:
        return -1
    elif my_roll == your_roll:
        return 0

# %%
one_round(1, 1)
# Out:
# 0

# %%
one_round(6, 5)
# Out:
# 1

# %%
one_round(7, -1)
# Out:
# -1

# %%
# Final correct version
def one_round(my_roll, your_roll):
    faces = np.arange(1,7)
    if sum(my_roll == faces) != 1 or sum(your_roll == faces) != 1:
        print('Please provide a number between 1 and 6')
    elif my_roll > your_roll:
        return 1
    elif my_roll < your_roll:
        return -1
    elif my_roll == your_roll:
        return 0

one_round(7, -1)
# Out:
# Please provide a number between 1 and 6

# %% [markdown]
# ### Random Selection

# %%
mornings = make_array('wake up', 'sleep in')

# %%
np.random.choice(mornings)
# Out:
# 'sleep in'

# %%
np.random.choice(mornings)
# Out:
# 'sleep in'

# %%
np.random.choice(mornings)
# Out:
# 'wake up'

# %% [markdown]
# We can also pass an argument that specifies how many times to make a random choice:

# %%
np.random.choice(mornings, 7)
# Out:
# array(['sleep in', 'sleep in', 'wake up', 'wake up', 'wake up', 'wake up',
#        'wake up'],
#       dtype='<U8')

# %%
sum(np.random.choice(mornings, 7) == 'wake up')
# Out:
# 6

# %%
sum(np.random.choice(mornings, 7) == 'sleep in')
# Out:
# 3

# %%
morning_week = np.random.choice(mornings, 7)
morning_week
# Out:
# array(['wake up', 'sleep in', 'sleep in', 'sleep in', 'wake up',
#        'sleep in', 'sleep in'],
#       dtype='<U8')

# %%
sum(morning_week == 'wake up')
# Out:
# 2

# %%
sum(morning_week == 'sleep in')
# Out:
# 5

# %% [markdown]
# ### Simulating the roll of a die

# %%
die_faces = np.arange(1, 7)

# %%
np.random.choice(die_faces)
# Out:
# 5

# %%
# Use the simulation to run one round of the game above.
def simulate_one_round():
    my_roll = np.random.choice(die_faces)
    your_roll = np.random.choice(die_faces)
    return one_round(my_roll, your_roll)

# %%
simulate_one_round()
# Out:
# -1

# %% [markdown]
# ### Appending Arrays

# %%
first = np.arange(4)
second = np.arange(10, 17)

# %%
np.append(first, 6)
# Out:
# array([0, 1, 2, 3, 6])

# %%
first
# Out:
# array([0, 1, 2, 3])

# %%
np.append(first, second)
# Out:
# array([ 0,  1,  2,  3, 10, 11, 12, 13, 14, 15, 16])

# %%
first
# Out:
# array([0, 1, 2, 3])

# %%
second
# Out:
# array([10, 11, 12, 13, 14, 15, 16])

# %% [markdown]
# ### Repeated Betting ###

# %%
#Create an array to store the results of the game.
results = make_array()

# %%
#Add to the array when the game is played once.
results = np.append(results, simulate_one_round())
results
# Out:
# array([ 1.])

# %%
#Add to the array when the game is played a second time after the above time.
results = np.append(results, simulate_one_round())
results
# Out:
# array([ 1.,  1.])

# %% [markdown]
# ## `For` Statements

# %%
for pet in make_array('cat', 'dog', 'rabbit'):
    print('I love my ' + pet)
# Out:
# I love my cat
# I love my dog
# I love my rabbit

# %%
# Iteration 1
pet = make_array('cat', 'dog', 'rabbit').item(0)
print('I love my ' + pet)

# Iteration 2
pet = make_array('cat', 'dog', 'rabbit').item(1)
print('I love my ' + pet)

# Iteration 3
pet = make_array('cat', 'dog', 'rabbit').item(2)
print('I love my ' + pet)
# Out:
# I love my cat
# I love my dog
# I love my rabbit

# %%
# Output a Range
for x in np.arange(2, 10, 2):
    print(f'x = {x}')
# Out:
# x = 2
# x = 4
# x = 6
# x = 8

# %% [markdown]
# ### Use For Statements to Run Simulations Many Times

# %%
##Create an loop to store the results of the game played several times in array.
game_outcomes = make_array()

for i in np.arange(5):
    game_outcomes = np.append(game_outcomes, simulate_one_round())
    
game_outcomes
# Out:
# array([-1., -1., -1.,  1., -1.])

# %%
game_outcomes = make_array()

for i in np.arange(10000):
    game_outcomes = np.append(game_outcomes, simulate_one_round())
    
game_outcomes
# Out:
# array([-1., -1., -1., ...,  0.,  0.,  1.])

# %%
#Determine how many outcomes are in the array.
len(game_outcomes)
# Out:
# 10000

# %%
#Display the results as a Table
results = Table().with_column('My winnings', game_outcomes)
results
# Out:
# My winnings
# -1
# -1
# -1
# -1
# 1
# -1
# 0
# -1
# -1
# -1
# ... (9990 rows omitted)

# %%
#Display the data of the table as a horizontal bar chart.
results.group('My winnings').barh('My winnings')

# %% [markdown]
# ## Optional: Advanced `where` ##

# %%
ages = make_array(16, 22, 18, 15, 19, 15, 16, 21)
age = Table().with_column('Age', ages)

# %%
age
# Out:
# Age
# 16
# 22
# 18
# 15
# 19
# 15
# 16
# 21

# %%
age.where('Age', are.above_or_equal_to(18))
# Out:
# Age
# 22
# 18
# 19
# 21

# %%
voter = ages >= 18

# %%
voter
# Out:
# array([False,  True,  True, False,  True, False, False,  True], dtype=bool)

# %%
age.where(voter)
# Out:
# Age
# 22
# 18
# 19
# 21

# %%
is_voter = are.above_or_equal_to(18)

# %%
type(is_voter)
# Out:
# datascience.predicates._combinable

# %%
is_voter(22)
# Out:
# True

# %%
is_voter(3)
# Out:
# False

# %%
age.apply(is_voter, 'Age')
# Out:
# array([False,  True,  True, False,  True, False, False,  True], dtype=bool)

# %%
ages >= 18
# Out:
# array([False,  True,  True, False,  True, False, False,  True], dtype=bool)

# %%
voter
# Out:
# array([False,  True,  True, False,  True, False, False,  True], dtype=bool)

# %%
def my_voter_function(x):
    return x >= 18

# %%
age.where('Age', are.above_or_equal_to(18))
# Out:
# Age
# 22
# 18
# 19
# 21

# %%
age.where(voter)
# Out:
# Age
# 22
# 18
# 19
# 21

# %%
age.where('Age', my_voter_function)
# Out:
# Age
# 22
# 18
# 19
# 21
