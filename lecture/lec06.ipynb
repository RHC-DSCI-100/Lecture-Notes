# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Lecture 6

# %% [markdown]
# ## Table Review: Welcome Survey

# %%
welcome = Table.read_table('welcome_survey_sp22.csv')
welcome.show(5)

# %%
# On average, how long do side-sleepers sleep?
side_sleepers = welcome.where('Sleep position', are.containing('side'))
np.average(side_sleepers.column('Hours of sleep'))

# %%
# How many students get at least 8 hours of sleep each night (on average)?
# First way: Query of Values that meet a criteria
welcome.where('Hours of sleep', are.above_or_equal_to(8)).num_rows

# %%
# Use the column() method to get an array of the result of the condition below
welcome.column('Hours of sleep') >= 8

# %%
# Second way: The number of values that are not zero
np.count_nonzero(welcome.column('Hours of sleep') >= 8)

# %%
# Third way: Adding the values in the array
np.sum(welcome.column('Hours of sleep') >= 8)

# %%
# Create a table with only the two sleep-related columns, 
# with names 'Hours' and 'Position'
two_col = welcome.select('Hours of sleep', 'Sleep position')
sleep = two_col.relabeled(0, 'Hours').relabeled(1, 'Position')
sleep.show(3)

# %%
# Second way
two_col = welcome.drop(
    'Handedness', 'Extraversion',
    'Pant leg', 'Number of textees',
    'Pets', 'Piercings',
    'Year', 'Extroversion')
sleep = two_col.relabeled(0, 'Hours').relabeled(1, 'Position')
sleep.show(3)

# %% [markdown]
# ## Discussion Question: NBA Salaries
#
# The table nba has columns player, position, and salary.
# <ol type = "a">
# <li> Create a table containing the records of all point guards (PG) who made more than $15M </li>
# <li> From the new table take out the value that is common to all of the records.</li>
# <li> Reflect: After evaluating these two expressions in order, what's the final result? </li>
# </ol>

# %%
nba = Table.read_table('nba_salaries.csv')
nba.show(3)

# %%
# Question (1) Create a table containing the records of all point guards (PG) who made more than $15M
guards = ...
guards.show(3)

# %%
# Question (2) From the new table take out the value that is common to all of the records.
guards = ...
guards.show(3)

# %% [markdown]
# ### Question (3) Reflect: After evaluating these two expressions in order, what's the final result?
#
# Reflect here

# %% [markdown]
# ## Census ##
# Creating a census: The process of collecting data about
#
# Understanding the column variables:<br>
# * SEX
# * AGE
#
# Problems with the census data collection:

# %%
full = Table.read_table('nc-est2019-agesex-res.csv')
full

# %%
partial = full.select('SEX', 'AGE', 'POPESTIMATE2014', 'POPESTIMATE2019')
partial.show(5)

# %%
us_pop = partial.relabeled(2, '2014').relabeled(3, '2019')
us_pop.show(5)

# %%
# From the newly created table, find the records for the ages over 100.

# %% [markdown]
# ### Percent Change ###
#
# The amount of increase or decrease relative to the initial value.</br>
# $Change = \dfrac{}{}*100$

# %%
# Percent Change in Population for 2014 vs 2019
us_pop.with_column(
    '% Diff', ( us_pop.column('2019') - us_pop.column('2014') ) / us_pop.column('2014')
).set_format('% Diff', PercentFormatter)

# %% [markdown]
# ### 2019 Sex Ratios ###
#
# Ratio:
#
# Proportion:

# %%
us_pop_2019 = us_pop.drop('2014')
us_pop_2019.show(3)

# %%
# Create a table from the newly created table that only displays the age category for the entire population.
all_ages = ...
all_ages

# %%
#Add a proportion column to easily see which gender has more
pop_2019 = all_ages.column('2019').item(0)
all_ages.with_column(
    'Proportion', all_ages.column('2019')/pop_2019
).set_format('Proportion', PercentFormatter)

# %%
preteen = us_pop_2019.where('AGE', are.between(10, 13))
preteen

# %%
# Write a table that contains all of the females from the 2019 table.
females_all_rows = ...

# Write a new table from the table you just created that does only includes valid ages.
females = ...
females.show(3)

# %%
# Write a table that contains all of the males from the 2019 table for all valid ages.
# Tip: Edit the code for the female table
males_all_rows = ...
males = ...
males.show(3)

# %% [markdown]
# #### Based on the tables above, what questions do you have?

# %% [markdown]
# ### $F:M$ Ratios ###
# $F:M$ means
#
# Statistically, we know that women outlive men. Let's explore that.
#
# * If $F = M$ then
# * If $F > M$ then
# * If $F < M$ then

# %%
f_to_m_ratios = females.column(2) / males.column(2)

ratios = Table().with_columns(
    'Age', females.column('AGE'),
    'F:M Ratio', f_to_m_ratios
)

# %%
ratios.sort('Age', descending=False)

# %% [markdown]
# #### What do you notice? What questions does that bring up?
#
#
# #### What are your hypotheses?

# %%
ratios.sort('Age').take(np.arange(, ))

# %% [markdown]
# ## Line Plot
# Displaying data in an easy to read format.

# %%
ratios.plot('Age', 'F:M Ratio')

# %% [markdown]
# #### What do you notice about the scale of the axes in the line plot? ####

# %%
ratios.plot('Age', 'F:M Ratio')
plots.ylim(0, 100) # Sets y-axis from 0 to 100
plots.show()

# %% [markdown]
# #### What do you notice when the x- and y-axis are the same scale?
#
# #### What questions or observations can be made about this data after looking at the two graphs? List as many as you can think of?
