# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# # Hypothesis Testing #
#
# A test that chooses between two views of how data were generated.
#
# Review the models we've seen so far: **Each model has two hypotheses:**
#
# * Null Hypothesis: Something that can be modeled. Based on an existing belief or neutral impact.
# * Alternative Hypothesis: Challenge to the model or existing belief. What you're trying to show is true.
#
# ***QUESTION: What were the hypotheses for each of the scenarios below?***
# * Talledega County Jury:
#     * Null Hypothesis ?
#     * Alternative Hypothesis ?
# * Mendel's flowers: What were the hypotheses?
#     * Null Hypothesis ?
#     * Alternative Hypothesis ?
# * Alameda Jury: What were the hypotheses?
#     * Null Hypothesis ?
#     * Alternative Hypothesis ?
#
# The statitician chooses a statistic to test the hypotheses:
#
# **Test Statistic: A value from the sample that helps determine which hypothesis is better supported.**
#
# ***QUESTION: What was the test statistic used for each of the scenarios below?***
# * Talledega County Jury:
# * Mendel's flowers:
# * Alameda Jury:
#
# The model is run as a simulation many times assuming the null is true.
#
# **Language of Hypothesis Tests:**
#
# * If data is not consistent with the null:
# * If data is consistent with the null:
#
# We will not say

# %% [markdown]
# ## The GSI's Defense ##

# %% [markdown]
# The students of one of the TA's at Berkeley  averaged a lower score than the the cohorts of the other TA's.
# The TA said it was by chance; the students in their group didn't think so. We can run statistical anaysis to see which is more likely to be true.
#
# What are the two hypotheses?
#
# * **Null:** ?
# * **Alternative:** ?
#
# What might be a good test statistic for this test?
#
# Load in the scores table. These are the scores of all the students on the midterm and which GSI they were assigned to.

# %%
scores = Table.read_table('scores_by_section.csv')
scores
# Out:
# Section | Midterm
# 1       | 22
# 2       | 12
# 2       | 23
# 2       | 14
# 1       | 20
# 3       | 25
# 4       | 19
# 1       | 24
# 5       | 8
# 6       | 14
# ... (349 rows omitted)

# %%
# COMPLETE: Determine how many students were in each GSI section.

scores.group('Section')
# Out:
# Section | count
# 1       | 32
# 2       | 32
# 3       | 27
# 4       | 30
# 5       | 33
# 6       | 32
# 7       | 24
# 8       | 29
# 9       | 30
# 10      | 34
# ... (2 rows omitted)

# %%
# Determine the midterm average for each section. 

scores.group('Section', np.average).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Section</th> <th>Midterm average</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1      </td> <td>15.5938        </td>
#         </tr>
#         <tr>
#             <td>2      </td> <td>15.125         </td>
#         </tr>
#         <tr>
#             <td>3      </td> <td>13.6667        </td>
#         </tr>
#         <tr>
#             <td>4      </td> <td>14.7667        </td>
#         </tr>
#         <tr>
#             <td>5      </td> <td>17.4545        </td>
#         </tr>
#         <tr>
#             <td>6      </td> <td>15.0312        </td>
#         </tr>
#         <tr>
#             <td>7      </td> <td>16.625         </td>
#         </tr>
#         <tr>
#             <td>8      </td> <td>16.3103        </td>
#         </tr>
#         <tr>
#             <td>9      </td> <td>14.5667        </td>
#         </tr>
#         <tr>
# ...

# %% [markdown]
# ***QUESTION: Which group seems to be significantly different?***
#
# ***QUESTION: If you were a student in this class and saw these averages, how would you feel if you were in that section?***

# %%
# COMPLETE: Assign the lowest average to this variable.

observed_average = min(scores.group('Section', np.average).column('Midterm average'))
observed_average
# Out:
# 13.666666666666666

# %%
# COMPLETE: Create a random sample from the data with the same amount of students in the concerning section.

random_sample = scores.sample(27, with_replacement=False)
random_sample
# Out:
# Section | Midterm
# 10      | 14
# 8       | 19
# 10      | 23
# 3       | 20
# 10      | 19
# 11      | 25
# 12      | 10
# 3       | 25
# 6       | 18
# 6       | 21
# ... (17 rows omitted)

# %%
# COMPLETE: Determine the average of the random sample.
np.average(random_sample.column('Midterm'))
# Out:
# 18.037037037037038

# %% [markdown]
# ***QUESTION: Comparing the random sample mean to the section's mean, are there any concerns?***

# %%
# Simulate one value of the test statistic under the hypothesis that the section is like a random sample from the class

def random_sample_midterm_avg():
    random_sample = scores.sample(27, with_replacement=False)
    return np.average(random_sample.column('Midterm'))

# %%
# COMPLETE: Simulate 50,000 copies of the test statistic

sample_averages = make_array()

for i in np.arange(50000):
    sample_averages = np.append(sample_averages, random_sample_midterm_avg())

# %% [markdown]
# ## Our Decision
#
# Simulate the test statistic under the null hypothesis; draw the histogram of the simulated values.</br>
# This displays the empirical distribution of the statistic under the null hypothesis and shows the likely values.
#
# We must determine if the data is consistent with the null or not.
#
# ***QUESTION: What would show the data is inconsistent with the null?***
#
# Data that is inconsistent with the null: The observed statistic is located ...

# %%
# Compare the simulated distribution of the statistic and the actual observed statistic
averages_tbl = Table().with_column('Random Sample Average', sample_averages)
averages_tbl.hist(bins = 20)
plots.scatter(observed_average, -0.01, color='red', s=120);

# %% [markdown]
# ### P-Value
# Formal name: Observed Significance Level
#
# The P-value is the probabililty, assuming the null hypothesis is true, that the test statistic is equal to the value that was observed in the data or is even further in the direction of the alternative. (P-value: probability value)
#
# The observed statistic being "In the Tail" as an area. (Probability of a continuous variable is given as the area under the curve from the value on.)
#
# * Statistically Significant:
# * Highly Statistically Significant:
#
# If we use a p-value cutoff of 5%, a p-value below that would mean the data is ... with the null.

# %% [markdown]
# #### Approach 1
# Calculate the p-value: Simulation area beyond observed value.
# How many times ... divided by the number of trials.
#
# Then see if that vallue is less than 5%.

# %%
np.count_nonzero(sample_averages <= observed_average) / 50000
# Out:
# 0.057540000000000001

# %% [markdown]
# #### Approach 2
# Find simulated value corresponding to 5% of 50,000 = 2500 (Convert the p-value cutoff into a simulated value.)
#
# Then see if the simulated value is greater than the observed value.

# %%
five_percent_point = averages_tbl.sort(0).column(0).item(2500)
five_percent_point
# Out:
# 13.592592592592593

# %%
observed_average
# Out:
# 13.666666666666666

# %% [markdown]
# ### Visual Representation of the P-value Compared to the Observed Statistic.

# %%
# COMPLETE: Create a histogram with 20 bins from the data.

averages_tbl.hist(bins = 20)

#This code will plot the observed average and a cutoff line for 5%.
plots.plot([five_percent_point, five_percent_point], [0, 0.35], color='gold', lw=2)
plots.title('Area to the left of the gold line: 5%');
plots.scatter(observed_average, -0.01, color='red', s=120);

# %% [markdown]
# ***QUESTION: Is the GSI's claim that the average being low was by chance statistically true?***
